# %%
import pandas as pd

# %%
df = pd.read_csv('c:\\Users\\shrey\\OneDrive\\Desktop\\Coding\\ISTE\\data\\survey_results_public.csv')

# %%
df.head(7)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
# 5           6  I agree  I am a developer by profession  35-44 years old
# 6           7  I agree  I am a developer by profession  35-44 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info
# Out:
# <bound method DataFrame.info of        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# ...

# %%
pd.set_option('display.max_columns',84)
pd.set_option('display.max_rows',84)

# %%
schema_df = pd.read_csv('c:\\Users\\shrey\\OneDrive\\Desktop\\Coding\\ISTE\\data\\survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.tail(7)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89177       89178  I agree  I am a developer by profession
# 89178       89179  I agree  I am a developer by profession
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89177     35-44 years old                                Employed, full-time
# 89178     45-54 years old                                Employed, full-time
# 89179     25-34 years old  Employed, full-time;Independent contractor, fr...
# 89180     18-24 years old             Student, full-time;Employed, part-time
# 89181   Prefer not to say                                I prefer not to say
# ...

# %%
people={
    "first_name":['Corey','Jane','Tom','Adam'],
    "last_name":['Schafer','Doe','Hanks','Doe'],
    "email":['coreysch@gmail.com','doejane@gmail.com','h.tom9@hotmail.com','A@email.com']
}

# %%
dff=pd.DataFrame(people)

# %%
dff
# Out:
#   first_name last_name               email
# 0      Corey   Schafer  coreysch@gmail.com
# 1       Jane       Doe   doejane@gmail.com
# 2        Tom     Hanks  h.tom9@hotmail.com
# 3       Adam       Doe         A@email.com

# %%
dff['email']
# Out:
# 0    coreysch@gmail.com
# 1     doejane@gmail.com
# 2    h.tom9@hotmail.com
# 3           A@email.com
# Name: email, dtype: object

# %%
type(dff['email'])
# Out:
# pandas.core.series.Series

# %%
dff.email
# Out:
# 0    coreysch@gmail.com
# 1     doejane@gmail.com
# 2    h.tom9@hotmail.com
# 3           A@email.com
# Name: email, dtype: object

# %%
dff[['last_name','email']]
# Out:
#   last_name               email
# 0   Schafer  coreysch@gmail.com
# 1       Doe   doejane@gmail.com
# 2     Hanks  h.tom9@hotmail.com
# 3       Doe         A@email.com

# %%
dff.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
dff.iloc[[0,1], 2]
# Out:
# 0    coreysch@gmail.com
# 1     doejane@gmail.com
# Name: email, dtype: object

# %%
dff
# Out:
#   first_name last_name               email
# 0      Corey   Schafer  coreysch@gmail.com
# 1       Jane       Doe   doejane@gmail.com
# 2        Tom     Hanks  h.tom9@hotmail.com
# 3       Adam       Doe         A@email.com

# %%
dff.loc[[0,1],['email','last_name']]
# Out:
#                 email last_name
# 0  coreysch@gmail.com   Schafer
# 1   doejane@gmail.com       Doe

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['Age'].value_counts()
# Out:
# 25-34 years old       33247
# 35-44 years old       20532
# 18-24 years old       17931
# 45-54 years old        8334
# Under 18 years old     4128
# 55-64 years old        3392
# 65 years or older      1171
# Prefer not to say       449
# Name: Age, dtype: int64

# %%
df.loc[0:5,'Age':'DevType']
# Out:
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# 1  25-34 years old                                Employed, full-time
# 2  45-54 years old                                Employed, full-time
# 3  25-34 years old                                Employed, full-time
# 4  25-34 years old  Employed, full-time;Independent contractor, fr...
# 5  35-44 years old                                Employed, full-time
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
# 5                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# ...

# %%
dff['email']
# Out:
# 0    coreysch@gmail.com
# 1     doejane@gmail.com
# 2    h.tom9@hotmail.com
# 3           A@email.com
# Name: email, dtype: object

# %%
dff.set_index('email',inplace=True)

# %%
dff
# Out:
#                    first_name last_name
# email
# coreysch@gmail.com      Corey   Schafer
# doejane@gmail.com        Jane       Doe
# h.tom9@hotmail.com        Tom     Hanks
# A@email.com              Adam       Doe

# %%
dff.index
# Out:
# Index(['coreysch@gmail.com', 'doejane@gmail.com', 'h.tom9@hotmail.com',
#        'A@email.com'],
#       dtype='object', name='email')

# %%
dff.loc['coreysch@gmail.com','last_name']
# Out:
# 'Schafer'

# %%
dff.reset_index(inplace=True)

# %%
dff
# Out:
#                 email first_name last_name
# 0  coreysch@gmail.com      Corey   Schafer
# 1   doejane@gmail.com       Jane       Doe
# 2  h.tom9@hotmail.com        Tom     Hanks
# 3         A@email.com       Adam       Doe

# %%
df.set_index('ResponseId',inplace=True)
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
schema_df.set_index('qid',inplace=True)

# %%
schema_df
# Out:
#                        qname  \
# qid
# QID16                     S0
# QID12               MetaInfo
# QID310                  Q310
# QID312                  Q120
# QID1                      S1
# QID2              MainBranch
# QID127                   Age
# QID296            Employment
# QID308            RemoteWork
# QID297      CodingActivities
# QID190                    S2
# QID25                EdLevel
# QID276             LearnCode
# QID281       LearnCodeOnline
# QID306  LearnCodeCoursesCert
# QID32              YearsCode
# QID34           YearsCodePro
# QID31                DevType
# QID29                OrgSize
# QID278     PurchaseInfluence
# QID322              TechList
# QID279            BuyNewTool
# QID6                 Country
# QID50               Currency
# QID51              CompTotal
# QID61                     S3
# QID233              Language
# QID262              Database
# QID263              Platform
# QID264              Webframe
# ...

# %%
schema_df.loc['QID297','question']
# Out:
# 'Which of the following best describes the code you write outside of work? Select all that apply.'

# %%
schema_df.sort_index(ascending=False)
# Out:
#                        qname  \
# qid
# QID91                     S4
# QID71                  OpSys
# QID61                     S3
# QID6                 Country
# QID51              CompTotal
# QID50               Currency
# QID34           YearsCodePro
# QID328                 AIDev
# QID327              AISearch
# QID326              Industry
# QID325                  SOAI
# QID324                 AIAcc
# QID322              TechList
# QID321                AIOpen
# QID320                AINext
# QID32              YearsCode
# QID319                AITool
# QID316                 AIBen
# QID315                AISent
# QID314              AISelect
# QID313                    S5
# QID312                  Q120
# QID310                  Q310
# QID31                DevType
# QID308            RemoteWork
# QID307       OfficeStackSync
# QID306  LearnCodeCoursesCert
# QID304      ProfessionalTech
# QID299               TBranch
# QID297      CodingActivities
# ...

# %%
#inplace permanently changes

# %%
filt = (dff['last_name'] == 'Doe') | (dff['first_name']=='Tom')

# %%
dff[filt]
# Out:
#                 email first_name last_name
# 1   doejane@gmail.com       Jane       Doe
# 2  h.tom9@hotmail.com        Tom     Hanks
# 3         A@email.com       Adam       Doe

# %%
dff.loc[filt,'email']
# Out:
# 1     doejane@gmail.com
# 2    h.tom9@hotmail.com
# 3           A@email.com
# Name: email, dtype: object

# %%
high_salary = (df['CompTotal'] > 100000)
countries = ['United States of America','India']
filt = df['Country'].isin(countries)

# %%
df.loc[filt,['Country','LanguageHaveWorkedWith','YearsCodePro']]
# Out:
#                              Country  \
# ResponseId
# 2           United States of America
# 3           United States of America
# 4           United States of America
# 7           United States of America
# 8           United States of America
# ...                              ...
# 89165                          India
# 89166                          India
# 89168                          India
# 89176       United States of America
# 89179       United States of America
#
#                                        LanguageHaveWorkedWith YearsCodePro
# ResponseId
# 2                                  HTML/CSS;JavaScript;Python            9
# 3                                  Bash/Shell (all shells);Go           23
# 4           Bash/Shell (all shells);HTML/CSS;JavaScript;PH...            7
# 7           Ada;Clojure;Elixir;Go;HTML/CSS;Java;JavaScript...            3
# 8           Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript            3
# ...

# %%
filt1=df['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt1,'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
filt1
# Out:
# ResponseId
# 1        False
# 2         True
# 3        False
# 4        False
# 5        False
#          ...
# 89180    False
# 89181     True
# 89182     True
# 89183     True
# 89184    False
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: bool

# %%
dff.columns= ['mail','first','last']

# %%
dff
# Out:
#                  mail  first     last
# 0  coreysch@gmail.com  Corey  Schafer
# 1   doejane@gmail.com   Jane      Doe
# 2  h.tom9@hotmail.com    Tom    Hanks
# 3         A@email.com   Adam      Doe

# %%
dff.columns = [x.upper() for x in dff.columns]

# %%
dff
# Out:
#                  MAIL  FIRST     LAST
# 0  coreysch@gmail.com  Corey  Schafer
# 1   doejane@gmail.com   Jane      Doe
# 2  h.tom9@hotmail.com    Tom    Hanks
# 3         A@email.com   Adam      Doe

# %%
dff.columns = dff.columns.str.replace('S','_')
dff
# Out:
#                  MAIL  FIR_T     LA_T
# 0  coreysch@gmail.com  Corey  Schafer
# 1   doejane@gmail.com   Jane      Doe
# 2  h.tom9@hotmail.com    Tom    Hanks
# 3         A@email.com   Adam      Doe

# %%
dff.rename(columns={'FIR_T':'first_name','LA_T':'last_name'},inplace=True)

# %%
dff
# Out:
#                  MAIL first_name last_name
# 0  coreysch@gmail.com      Corey   Schafer
# 1   doejane@gmail.com       Jane       Doe
# 2  h.tom9@hotmail.com        Tom     Hanks
# 3         A@email.com       Adam       Doe

# %%
dff.loc[2] = ['j.smith15@hotmail.com','John','Smith']

# %%
dff
# Out:
#                     MAIL first_name last_name
# 0     coreysch@gmail.com      Corey   Schafer
# 1      doejane@gmail.com       Jane       Doe
# 2  j.smith15@hotmail.com       John     Smith
# 3            A@email.com       Adam       Doe

# %%
dff.loc[2, ['last_name','MAIL']] = ['Doe','JohnDoe@mailmail.com']

# %%
dff
# Out:
#                    MAIL first_name last_name
# 0    coreysch@gmail.com      Corey   Schafer
# 1     doejane@gmail.com       Jane       Doe
# 2  JohnDoe@mailmail.com       John       Doe
# 3           A@email.com       Adam       Doe

# %%
dff.loc[2,'last_name'] = 'Smith'

# %%
dff
# Out:
#                    MAIL first_name last_name
# 0    coreysch@gmail.com      Corey   Schafer
# 1     doejane@gmail.com       Jane       Doe
# 2  JohnDoe@mailmail.com       John     Smith
# 3           A@email.com       Adam       Doe

# %%
filt = (dff['MAIL'] == 'JohnDoe@mailmail.com')
dff[filt]['last_name']
# Out:
# 2    Smith
# Name: last_name, dtype: object

# %%
 #making email lowercase

# %%
dff['MAIL']= dff['MAIL'].str.lower()

# %%
dff
# Out:
#                    MAIL first_name last_name
# 0    coreysch@gmail.com      Corey   Schafer
# 1     doejane@gmail.com       Jane       Doe
# 2  johndoe@mailmail.com       John     Smith
# 3           a@email.com       Adam       Doe

# %%
#apply, map, applymap, replace

# %%
dff['MAIL'].apply(len)
# Out:
# 0    18
# 1    17
# 2    20
# 3    11
# Name: MAIL, dtype: int64

# %%
def update_mail(MAIL):
    return MAIL.upper()

# %%
dff['MAIL'].apply(update_mail)
# Out:
# 0      COREYSCH@GMAIL.COM
# 1       DOEJANE@GMAIL.COM
# 2    JOHNDOE@MAILMAIL.COM
# 3             A@EMAIL.COM
# Name: MAIL, dtype: object

# %%
dff
# Out:
#                    MAIL first_name last_name
# 0    coreysch@gmail.com      Corey   Schafer
# 1     doejane@gmail.com       Jane       Doe
# 2  johndoe@mailmail.com       John     Smith
# 3           a@email.com       Adam       Doe

# %%
dff['MAIL'] = dff['MAIL'].apply(update_mail)
dff
# Out:
#                    MAIL first_name last_name
# 0    COREYSCH@GMAIL.COM      Corey   Schafer
# 1     DOEJANE@GMAIL.COM       Jane       Doe
# 2  JOHNDOE@MAILMAIL.COM       John     Smith
# 3           A@EMAIL.COM       Adam       Doe

# %%
dff['MAIL'] = dff['MAIL'].apply(lambda x: x.lower())

# %%
dff
# Out:
#                    MAIL first_name last_name
# 0    coreysch@gmail.com      Corey   Schafer
# 1     doejane@gmail.com       Jane       Doe
# 2  johndoe@mailmail.com       John     Smith
# 3           a@email.com       Adam       Doe

# %%
dff.apply(len, axis= 'columns')
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# dtype: int64

# %%
len(dff['MAIL'])
# Out:
# 4

# %%
dff.apply(pd.Series.min)
#makes more sense with numerical data
# Out:
# MAIL          a@email.com
# first_name           Adam
# last_name             Doe
# dtype: object

# %%
dff.apply(lambda x: x.min())
# Out:
# MAIL          a@email.com
# first_name           Adam
# last_name             Doe
# dtype: object

# %%
dff.applymap(len)
# Out:
#    MAIL  first_name  last_name
# 0    18           5          7
# 1    17           4          3
# 2    20           4          5
# 3    11           4          3

# %%
dff.applymap(str.lower)
# Out:
#                    MAIL first_name last_name
# 0    coreysch@gmail.com      corey   schafer
# 1     doejane@gmail.com       jane       doe
# 2  johndoe@mailmail.com       john     smith
# 3           a@email.com       adam       doe

# %%
# dff['first_name'].map({'Corey':'Chris'})

# %%
dff['first_name'] = dff['first_name'].replace({'Corey':'Chris'})

# %%
dff
# Out:
#                    MAIL first_name last_name
# 0    coreysch@gmail.com      Chris   Schafer
# 1     doejane@gmail.com       Jane       Doe
# 2  johndoe@mailmail.com       John     Smith
# 3           a@email.com       Adam       Doe

# %%
df.rename(columns={'CompTotal': 'SalaryUSD'},inplace=True)

# %%
df["SalaryUSD"]
# Out:
# ResponseId
# 1                 NaN
# 2        2.850000e+05
# 3        2.500000e+05
# 4        1.560000e+05
# 5        1.320000e+06
#              ...
# 89180    2.000000e+05
# 89181             NaN
# 89182             NaN
# 89183             NaN
# 89184    3.300000e+09
# Name: SalaryUSD, Length: 89184, dtype: float64

# %%
df['SOAccount'].map({'Yes':True,'No':False})
# Out:
# ResponseId
# 1          NaN
# 2         True
# 3         True
# 4         True
# 5        False
#          ...
# 89180     True
# 89181     True
# 89182      NaN
# 89183    False
# 89184     True
# Name: SOAccount, Length: 89184, dtype: object

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes':True,'No':False})

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
dff['first_name']+ ' '+ dff['last_name']
# Out:
# 0    Chris Schafer
# 1         Jane Doe
# 2       John Smith
# 3         Adam Doe
# dtype: object

# %%
dff['full_name'] = dff['first_name']+ ' '+ dff['last_name']

# %%
dff
# Out:
#                    MAIL first_name last_name      full_name
# 0    coreysch@gmail.com      Chris   Schafer  Chris Schafer
# 1     doejane@gmail.com       Jane       Doe       Jane Doe
# 2  johndoe@mailmail.com       John     Smith     John Smith
# 3           a@email.com       Adam       Doe       Adam Doe

# %%
dff.drop(columns=['first_name','last_name'],inplace=True)

# %%
dff
# Out:
#                    MAIL      full_name
# 0    coreysch@gmail.com  Chris Schafer
# 1     doejane@gmail.com       Jane Doe
# 2  johndoe@mailmail.com     John Smith
# 3           a@email.com       Adam Doe

# %%
dff['full_name'].str.split(' ',expand=True)
# Out:
#        0        1
# 0  Chris  Schafer
# 1   Jane      Doe
# 2   John    Smith
# 3   Adam      Doe

# %%
dff[['first','last']] = dff['full_name'].str.split(' ',expand=True)

# %%
dff
# Out:
#                    MAIL      full_name  first     last
# 0    coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 1     doejane@gmail.com       Jane Doe   Jane      Doe
# 2  johndoe@mailmail.com     John Smith   John    Smith
# 3           a@email.com       Adam Doe   Adam      Doe

# %%
dff.append({'first': 'Tony'},ignore_index=True)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_19076\1670566333.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff.append({'first': 'Tony'},ignore_index=True)
#                    MAIL      full_name  first     last
# 0    coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 1     doejane@gmail.com       Jane Doe   Jane      Doe
# 2  johndoe@mailmail.com     John Smith   John    Smith
# 3           a@email.com       Adam Doe   Adam      Doe
# 4                   NaN            NaN   Tony      NaN

# %%
people={
    "first":['Tony','Steve'],
    "last":['Stark','Rogers'],
    "MAIL":['tonyisdead@gmail.com','steveisold@hotmail.com']
}
df2= pd.DataFrame(people)

# %%
dff = dff.append(df2, ignore_index=True, sort = False)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_19076\3454211416.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff = dff.append(df2, ignore_index=True, sort = False)

# %%
dff
# Out:
#                      MAIL      full_name  first     last
# 0      coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 1       doejane@gmail.com       Jane Doe   Jane      Doe
# 2    johndoe@mailmail.com     John Smith   John    Smith
# 3             a@email.com       Adam Doe   Adam      Doe
# 4    tonyisdead@gmail.com            NaN   Tony    Stark
# 5  steveisold@hotmail.com            NaN  Steve   Rogers

# %%
dff.drop(index = 4,inplace= True)

# %%
filt = dff['last'] == 'Doe'
dff.drop(index = dff[filt].index)
# Out:
#                      MAIL      full_name  first     last
# 0      coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 2    johndoe@mailmail.com     John Smith   John    Smith
# 5  steveisold@hotmail.com            NaN  Steve   Rogers

# %%
dff.sort_values(by='last',ascending= False)
# Out:
#                      MAIL      full_name  first     last
# 2    johndoe@mailmail.com     John Smith   John    Smith
# 0      coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 5  steveisold@hotmail.com            NaN  Steve   Rogers
# 1       doejane@gmail.com       Jane Doe   Jane      Doe
# 3             a@email.com       Adam Doe   Adam      Doe

# %%
dff.sort_values(by=['last','first'],ascending= False)
#sorts last name in descending order, if last name is same then sorted in descending order by first name
# Out:
#                      MAIL      full_name  first     last
# 2    johndoe@mailmail.com     John Smith   John    Smith
# 0      coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 5  steveisold@hotmail.com            NaN  Steve   Rogers
# 1       doejane@gmail.com       Jane Doe   Jane      Doe
# 3             a@email.com       Adam Doe   Adam      Doe

# %%
dff.sort_values(by=['last','first'],ascending= [False,True],inplace=True)
#sorts last name in descending order, if last name is same then sorted in ascending order by first name

# %%
dff
# Out:
#                      MAIL      full_name  first     last
# 2    johndoe@mailmail.com     John Smith   John    Smith
# 0      coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 5  steveisold@hotmail.com            NaN  Steve   Rogers
# 3             a@email.com       Adam Doe   Adam      Doe
# 1       doejane@gmail.com       Jane Doe   Jane      Doe

# %%
dff.sort_index()
#sorted in the order data is added,i.e,by their index
# Out:
#                      MAIL      full_name  first     last
# 0      coreysch@gmail.com  Chris Schafer  Chris  Schafer
# 1       doejane@gmail.com       Jane Doe   Jane      Doe
# 2    johndoe@mailmail.com     John Smith   John    Smith
# 3             a@email.com       Adam Doe   Adam      Doe
# 5  steveisold@hotmail.com            NaN  Steve   Rogers

# %%
dff['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 5     Rogers
# 0    Schafer
# 2      Smith
# Name: last, dtype: object

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=[True,False],inplace=True)

# %%
df['Country'].head(50)
# Out:
# ResponseId
# 88348    Afghanistan
# 1335     Afghanistan
# 57362    Afghanistan
# 17873    Afghanistan
# 36049    Afghanistan
# 53322    Afghanistan
# 86039    Afghanistan
# 41679    Afghanistan
# 39427    Afghanistan
# 37956    Afghanistan
# 2642     Afghanistan
# 61076    Afghanistan
# 59006    Afghanistan
# 67794    Afghanistan
# 2301     Afghanistan
# 3911     Afghanistan
# 4222     Afghanistan
# 4410     Afghanistan
# 10143    Afghanistan
# 10377    Afghanistan
# 14420    Afghanistan
# 15959    Afghanistan
# 20378    Afghanistan
# 21498    Afghanistan
# 21673    Afghanistan
# 23095    Afghanistan
# 26532    Afghanistan
# 27885    Afghanistan
# 29006    Afghanistan
# 31397    Afghanistan
# 33928    Afghanistan
# 35178    Afghanistan
# 38328    Afghanistan
# 39319    Afghanistan
# 44601    Afghanistan
# 44908    Afghanistan
# 46137    Afghanistan
# 46705    Afghanistan
# 47692    Afghanistan
# 49208    Afghanistan
# 51789    Afghanistan
# 53883    Afghanistan
# ...

# %%
df['Country'].tail(50)
# Out:
# ResponseId
# 87127    NaN
# 87152    NaN
# 87180    NaN
# 87227    NaN
# 87302    NaN
# 87327    NaN
# 87349    NaN
# 87363    NaN
# 87374    NaN
# 87376    NaN
# 87387    NaN
# 87495    NaN
# 87543    NaN
# 87549    NaN
# 87620    NaN
# 87621    NaN
# 87679    NaN
# 87710    NaN
# 87741    NaN
# 87764    NaN
# 87782    NaN
# 87860    NaN
# 87865    NaN
# 87912    NaN
# 87935    NaN
# 87951    NaN
# 87981    NaN
# 87993    NaN
# 88025    NaN
# 88044    NaN
# 88046    NaN
# 88133    NaN
# 88239    NaN
# 88259    NaN
# 88426    NaN
# 88452    NaN
# 88507    NaN
# 88559    NaN
# 88567    NaN
# 88610    NaN
# 88632    NaN
# 88690    NaN
# 88727    NaN
# 88734    NaN
# 88794    NaN
# 88821    NaN
# 88829    NaN
# 88831    NaN
# 89029    NaN
# 89160    NaN
# Name: Country, dtype: object

# %%
df[['Country','SalaryUSD']].head(10)
# Out:
#                 Country    SalaryUSD
# ResponseId
# 88348       Afghanistan  932464379.0
# 1335        Afghanistan     210000.0
# 57362       Afghanistan     200000.0
# 17873       Afghanistan     100000.0
# 36049       Afghanistan      80000.0
# 53322       Afghanistan      69420.0
# 86039       Afghanistan      68000.0
# 41679       Afghanistan      56666.0
# 39427       Afghanistan       4200.0
# 37956       Afghanistan       3600.0

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 56323    5.000000e+46
# 18464    1.000000e+21
# 43557    1.000000e+16
# 49554    1.000000e+16
# 35780    1.000000e+15
# 15440    4.567887e+12
# 33079    1.000000e+11
# 19680    2.239672e+10
# 56854    1.980000e+10
# 9176     1.840199e+10
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 56323       I agree                     I am a developer by profession
# 18464       I agree                     I am a developer by profession
# 43557       I agree                     I am a developer by profession
# 49554       I agree  I am not primarily a developer, but I write co...
# 35780       I agree                     I am a developer by profession
# 15440       I agree                     I am a developer by profession
# 33079       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 56854       I agree  I am not primarily a developer, but I write co...
# 9176        I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 56323       25-34 years old
# 18464       25-34 years old
# 43557       18-24 years old
# 49554       25-34 years old
# ...

# %%
df.nsmallest(10,'SalaryUSD')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 59006       I agree                     I am a developer by profession
# 67794       I agree                     I am a developer by profession
# 4351        I agree                     I am a developer by profession
# 53788       I agree                     I am a developer by profession
# 8984        I agree  I am not primarily a developer, but I write co...
# 51707       I agree                     I am a developer by profession
# 74558       I agree  I am not primarily a developer, but I write co...
# 83555       I agree                     I am a developer by profession
# 88950       I agree  I am not primarily a developer, but I write co...
# 10731       I agree  I am not primarily a developer, but I write co...
#
#                           Age  \
# ResponseId
# 59006         35-44 years old
# 67794         18-24 years old
# 4351          18-24 years old
# 53788         35-44 years old
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 115000.0

# %%
df.median()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_19076\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# SalaryUSD              115000.0
# SOAccount                   1.0
# WorkExp                     9.0
# ConvertedCompYearly     74963.0
# dtype: float64

# %%
df.describe()
# Out:
#           SalaryUSD       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df['SalaryUSD'].count()
# Out:
# 48225

# %%
df['Age'].value_counts()
# Out:
# 25-34 years old       33247
# 35-44 years old       20532
# 18-24 years old       17931
# 45-54 years old        8334
# Under 18 years old     4128
# 55-64 years old        3392
# 65 years or older      1171
# Prefer not to say       449
# Name: Age, dtype: int64

# %%
df['DevType'].value_counts()
# Out:
# Developer, full-stack                            25735
# Developer, back-end                              13745
# Developer, front-end                              5071
# Developer, desktop or enterprise applications     3904
# Other (please specify):                           3080
# Developer, mobile                                 2597
# Engineering manager                               2033
# Student                                           1996
# Developer, embedded applications or devices       1845
# Data scientist or machine learning specialist     1588
# DevOps specialist                                 1387
# Academic researcher                               1354
# Research & Development role                       1353
# Senior Executive (C-Suite, VP, etc.)              1332
# Engineer, data                                    1248
# Cloud infrastructure engineer                     1036
# Developer, game or graphics                        866
# ...

# %%
df['DevType'].value_counts(normalize=True)
#given in percentage of total form
# Out:
# Developer, full-stack                            0.334777
# Developer, back-end                              0.178804
# Developer, front-end                             0.065967
# Developer, desktop or enterprise applications    0.050786
# Other (please specify):                          0.040067
# Developer, mobile                                0.033783
# Engineering manager                              0.026447
# Student                                          0.025965
# Developer, embedded applications or devices      0.024001
# Data scientist or machine learning specialist    0.020658
# DevOps specialist                                0.018043
# Academic researcher                              0.017614
# Research & Development role                      0.017601
# Senior Executive (C-Suite, VP, etc.)             0.017328
# Engineer, data                                   0.016235
# Cloud infrastructure engineer                    0.013477
# ...

# %%
#split, apply function, combine results

# %%
df['Country'].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 185, dtype: int64

# %%
cntrygrp = df.groupby(['Country'])

# %%
#object contains multiple groups

# %%
cntrygrp.get_group('India')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 50306       I agree                     I am a developer by profession
# 15398       I agree                     I am a developer by profession
# 72666       I agree                     I am a developer by profession
# 86269       I agree  I am not primarily a developer, but I write co...
# 10000       I agree                     I am a developer by profession
# ...             ...                                                ...
# 89069       I agree  I am not primarily a developer, but I write co...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 50306          18-24 years old
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['DevType'].value_counts()
# Out:
# Developer, full-stack                            1523
# Developer, back-end                               882
# Developer, front-end                              484
# Developer, mobile                                 289
# Student                                           175
# Developer, desktop or enterprise applications     137
# Other (please specify):                           116
# Data scientist or machine learning specialist     110
# Engineering manager                                89
# Engineer, data                                     71
# Research & Development role                        59
# DevOps specialist                                  58
# Developer, embedded applications or devices        53
# Senior Executive (C-Suite, VP, etc.)               47
# Developer, QA or test                              45
# Data or business analyst                           43
# Project manager                                    42
# ...

# %%
cntrygrp['DevType'].value_counts().head(50)
# Out:
# Country      DevType
# Afghanistan  Developer, full-stack                            16
#              Developer, back-end                               7
#              Academic researcher                               6
#              Developer, desktop or enterprise applications     4
#              Other (please specify):                           4
#              Developer, mobile                                 2
#              Blockchain                                        1
#              DevOps specialist                                 1
#              Developer, front-end                              1
#              Developer, game or graphics                       1
#              Marketing or sales professional                   1
#              Research & Development role                       1
#              Security professional                             1
# Albania      Developer, full-stack                            15
# ...

# %%
cntrygrp['DevType'].value_counts().loc['India']
#same result using filter
#but can use this method without creating filter for each country
# Out:
# DevType
# Developer, full-stack                            1523
# Developer, back-end                               882
# Developer, front-end                              484
# Developer, mobile                                 289
# Student                                           175
# Developer, desktop or enterprise applications     137
# Other (please specify):                           116
# Data scientist or machine learning specialist     110
# Engineering manager                                89
# Engineer, data                                     71
# Research & Development role                        59
# DevOps specialist                                  58
# Developer, embedded applications or devices        53
# Senior Executive (C-Suite, VP, etc.)               47
# Developer, QA or test                              45
# Data or business analyst                           43
# Project manager                                    42
# ...
